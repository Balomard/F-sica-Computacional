# %% [markdown]
# # Programa 1: Codigo de bash a python 1

# %% [markdown]
# ```python
# bash_code = """
# Código en Bash que fue la base:
# x=100.0
# for num in {1..100}
# do
#   x=$(echo "c($x)+s($x)" | bc -l)
#   echo $x
# done
# """

# %%
import numpy as np
import matplotlib.pyplot as plt

x = 100.0
y = range(1, 101)

for y_value in y:
    x = np.cos(x) + np.sin(x) + y_value
    print(f"{x:.6g}")

# %% [markdown]
# # Programa 2:Codigo de bash a python 2

# %% [markdown]
# ```python
# bash_code = """
# Código en Bash que fue la base:
#
#     x=0.100
# r = 1.00
# for i in {1..400}
# do
# r=`echo "$r + 0.01" | bc -l`
#
# for num in {1..300}
# do
#    x=`echo "$r*$x*(1-$x)"| bc -l`
#    if [ $num -gt 200 ]
#    then
#       echo $r $x
#    fi
# done
# done
# """

# %%
import math


x = 0.100
r = 1.00


for i in range(1, 401):
    r += 0.01


    for num in range(1, 301):
        x = r * x * (1 - x)


        if num < 200:
            print(r, x)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.749999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# 4.759999999999942 -inf
# ...
